# %%
import numpy as np
import pandas as pd

# %%
np.set_printoptions(precision=4)

# %% [markdown]
# ## All files

# %%
files = !ls ../records/game_reg/

# %%
datasets = []
for file in files:
    datasets.append(pd.read_csv('../records/game_reg/{}'.format(file), index_col=0))
all_data = pd.concat(datasets, ignore_index=True)
all_data.shape
# Out:
# (545142, 11)

# %%
all_data.head(5)
# Out:
#    cactus1  cactus2  cactus3  ptera1x  ptera1y  ptera2x  ptera2y  ptera3x  \
# 0      636      640      640      640       95      640       95      640
# 1      632      640      640      640       95      640       95      640
# 2      628      640      640      640       95      640       95      640
# 3      624      640      640      640       95      640       95      640
# 4      620      640      640      640       95      640       95      640
#
#    ptera3y  isJumping  isDucking
# 0       95          0          0
# 1       95          0          0
# 2       95          0          0
# 3       95          0          0
# 4       95          0          0

# %%
#all_data['output'] = 2*all_data['isJumping'] + all_data['isDucking']
#all_data[all_data['output'] > 2] = 2
#train_cols = ['cactus1', 'cactus2', 'cactus3', 'ptera1x', 'ptera1y', 'ptera2x', 'ptera2y', 'ptera3x', 'ptera3y']
train_cols = ['cactus1', 'ptera1x', 'ptera1y']
data = all_data[train_cols]
data.describe()
# Out:
#              cactus1        ptera1x        ptera1y
# count  545142.000000  545142.000000  545142.000000
# mean      238.451594     484.949727     105.975617
# std       181.133262     216.287262      16.900716
# min       -40.000000     -46.000000      95.000000
# 25%        88.000000     334.000000      95.000000
# 50%       216.000000     640.000000      95.000000
# 75%       372.000000     640.000000     132.000000
# max       640.000000     642.000000     132.000000

# %%
#data.values[data.values < 0] = 0

# %%
data.min()
# Out:
# cactus1   -40
# ptera1x   -46
# ptera1y    95
# dtype: int64

# %%
data.max()
# Out:
# cactus1    640
# ptera1x    642
# ptera1y    132
# dtype: int64

# %%
data.max() - data.min()
# Out:
# cactus1    680
# ptera1x    688
# ptera1y     37
# dtype: int64

# %%
normalized=(data-data.min())/(data.max()-data.min())
normalized.describe()
# Out:
#              cactus1        ptera1x        ptera1y
# count  545142.000000  545142.000000  545142.000000
# mean        0.409488       0.771729       0.296638
# std         0.266372       0.314371       0.456776
# min         0.000000       0.000000       0.000000
# 25%         0.188235       0.552326       0.000000
# 50%         0.376471       0.997093       0.000000
# 75%         0.605882       0.997093       1.000000
# max         1.000000       1.000000       1.000000

# %%
normalized.head(5)
# Out:
#     cactus1   ptera1x  ptera1y
# 0  0.994118  0.997093      0.0
# 1  0.988235  0.997093      0.0
# 2  0.982353  0.997093      0.0
# 3  0.976471  0.997093      0.0
# 4  0.970588  0.997093      0.0

# %%
normalized['ptera1y'] = 1 - normalized['ptera1y']
normalized.head(10)
# Out:
#     cactus1   ptera1x  ptera1y
# 0  0.994118  0.997093      1.0
# 1  0.988235  0.997093      1.0
# 2  0.982353  0.997093      1.0
# 3  0.976471  0.997093      1.0
# 4  0.970588  0.997093      1.0
# 5  0.964706  0.997093      1.0
# 6  0.958824  0.997093      1.0
# 7  0.952941  0.997093      1.0
# 8  0.947059  0.997093      1.0
# 9  0.941176  0.997093      1.0

# %%
X_train = 1 - np.array(normalized.values, dtype='float32')
Y_train = np.array(all_data['isJumping'].values, dtype='int32')
#Y_train = np.array(data['isJumping'].values, dtype='int32')
X_train[:10]
# Out:
# array([[0.0059, 0.0029, 0.    ],
#        [0.0118, 0.0029, 0.    ],
#        [0.0176, 0.0029, 0.    ],
#        [0.0235, 0.0029, 0.    ],
#        [0.0294, 0.0029, 0.    ],
#        [0.0353, 0.0029, 0.    ],
#        [0.0412, 0.0029, 0.    ],
#        [0.0471, 0.0029, 0.    ],
#        [0.0529, 0.0029, 0.    ],
#        [0.0588, 0.0029, 0.    ]], dtype=float32)

# %%
list(set(X_train[:,2]))
# Out:
# [0.0, 1.0]

# %%
def sigmoid(x):
    return 1/(1+np.exp(-16*(x-0.7)))

# %%
#X_train[:,0:2] = sigmoid(X_train[:,0:2])
X_train = sigmoid(X_train)

# %%
X_train[:10]
# Out:
# array([[1.5023e-05, 1.4325e-05, 1.3674e-05],
#        [1.6506e-05, 1.4325e-05, 1.3674e-05],
#        [1.8135e-05, 1.4325e-05, 1.3674e-05],
#        [1.9925e-05, 1.4325e-05, 1.3674e-05],
#        [2.1891e-05, 1.4325e-05, 1.3674e-05],
#        [2.4051e-05, 1.4325e-05, 1.3674e-05],
#        [2.6425e-05, 1.4325e-05, 1.3674e-05],
#        [2.9033e-05, 1.4325e-05, 1.3674e-05],
#        [3.1898e-05, 1.4325e-05, 1.3674e-05],
#        [3.5046e-05, 1.4325e-05, 1.3674e-05]], dtype=float32)

# %%
list(set(X_train[:,2]))
# Out:
# [1.3674011e-05, 0.99183744]

# %%
norm_data = pd.DataFrame(X_train, columns=['cactus', 'pterax', 'pteray'])

# %%
norm_data.head()
# Out:
#      cactus    pterax    pteray
# 0  0.000015  0.000014  0.000014
# 1  0.000017  0.000014  0.000014
# 2  0.000018  0.000014  0.000014
# 3  0.000020  0.000014  0.000014
# 4  0.000022  0.000014  0.000014

# %%
norm_data['y'] = Y_train

# %%
norm_data.head()
# Out:
#      cactus    pterax    pteray  y
# 0  0.000015  0.000014  0.000014  0
# 1  0.000017  0.000014  0.000014  0
# 2  0.000018  0.000014  0.000014  0
# 3  0.000020  0.000014  0.000014  0
# 4  0.000022  0.000014  0.000014  0

# %%
norm_data.to_csv('../records/datasets/clean_batch_large.csv', index=False)

# %%
pd.read_csv('../records/datasets/clean_batch_big.csv')
